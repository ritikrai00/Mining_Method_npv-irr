# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikrai00/Mining_Method_npv-irr/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/updated_mining_projects.csv')
df.head()
# Out:
#                Mining_Method  Depth_m  Ore_Grade  Stripping_Ratio  \
# 0       Underground-Longwall      356      54.57             5.47
# 1        Underground-General      461      33.24             8.95
# 2                   Opencast      146      64.01             2.13
# 3        Underground-General      734      30.90             3.15
# 4  Underground-Bord & Pillar      436      58.94             8.52
#
#    Capital_Cost_Million_INR  Operating_Cost_per_Ton_INR  \
# 0                    400.73                     3503.37
# 1                    744.81                     4699.98
# 2                    291.57                     1084.02
# 3                    201.57                     4041.39
# 4                    346.64                     1168.85
#
#    Annual_Production_Tons  Mine_Life_Years  NPV_Million_INR  IRR_Percent  \
# 0                 4595433               13          1003.75        19.18
# 1                 3565685               17           952.28        14.31
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the updated dataset
df = pd.read_csv('/content/updated_mining_projects.csv')

# Summary statistics
print("🔹 Summary Statistics:")
print(df.describe())

# Check data types and nulls
print("\n🔹 Dataset Info:")
print(df.info())

# Distribution plots for numeric variables
numeric_cols = ['Depth_m', 'Ore_Grade', 'Stripping_Ratio', 'Capital_Cost_Million_INR',
                'Operating_Cost_per_Ton_INR', 'Annual_Production_Tons', 'Mine_Life_Years',
                'NPV_Million_INR', 'IRR_Percent', 'Payback_Period_Years', 'Profitability_Index']

for col in numeric_cols:
    plt.figure(figsize=(6, 3))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.tight_layout()
    plt.show()
# Out:
# 🔹 Summary Statistics:
#           Depth_m  Ore_Grade  Stripping_Ratio  Capital_Cost_Million_INR  \
# count  500.000000  500.00000       500.000000                500.000000
# mean   517.784000   50.64794         5.617120                566.206020
# std    267.072944   11.44459         2.492311                260.939785
# min     53.000000   30.05000         1.000000                101.020000
# 25%    289.750000   40.38250         3.515000                349.247500
# 50%    496.500000   50.82500         5.665000                560.525000
# 75%    744.000000   60.63000         7.700000                788.012500
# max    999.000000   70.00000         9.960000                999.380000
#
#        Operating_Cost_per_Ton_INR  Annual_Production_Tons  Mine_Life_Years  \
# count                  500.000000            5.000000e+02       500.000000
# mean                  2828.520600            2.640025e+06        16.852000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numeric features for correlation
numeric_cols = ['Depth_m', 'Ore_Grade', 'Stripping_Ratio', 'Capital_Cost_Million_INR',
                'Operating_Cost_per_Ton_INR', 'Annual_Production_Tons', 'Mine_Life_Years',
                'NPV_Million_INR', 'IRR_Percent', 'Payback_Period_Years', 'Profitability_Index']

# Compute correlation matrix
corr_matrix = df[numeric_cols].corr()

# Plot heatmap
plt.figure(figsize=(9, 4))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('📊 Correlation Heatmap')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample subset to avoid clutter
pairplot_features = ['NPV_Million_INR', 'IRR_Percent', 'Capital_Cost_Million_INR', 'Operating_Cost_per_Ton_INR']
sns.pairplot(df[pairplot_features + ['Mining_Method']], hue="Mining_Method", diag_kind='kde', corner=True)
plt.suptitle("📉 Pair Plot of Financial Indicators by Mining Method", y=1.02)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Mining_Method', y='NPV_Million_INR', palette='Set2')
plt.title("📦 NPV by Mining Method")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-c13ddbddaa5c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Mining_Method', y='NPV_Million_INR', palette='Set2')
# <ipython-input-37-c13ddbddaa5c>:5: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='Mining_Method', palette='pastel')
plt.title("🔢 Project Count per Mining Method")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-38-3735fc924980>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Mining_Method', palette='pastel')
# <ipython-input-38-3735fc924980>:5: UserWarning: Glyph 128290 (\N{INPUT SYMBOL FOR NUMBERS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128290 (\N{INPUT SYMBOL FOR NUMBERS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='Mechanization_Level', hue='Mining_Method')
plt.title("⚙️ Mechanization Level by Mining Method")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='Labor_Intensity', hue='Mining_Method')
plt.title("👷 Labor Intensity by Mining Method")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-39-9382d84cb14b>:10: UserWarning: Glyph 128119 (\N{CONSTRUCTION WORKER}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128119 (\N{CONSTRUCTION WORKER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 1. Label encode categorical columns
categorical_cols = ['Mining_Method', 'Labor_Intensity', 'Mechanization_Level']
le_dict = {}  # to preserve mappings for possible inverse transform

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    le_dict[col] = le

# 2. Separate features (X) and target (y)
X = df.drop('Mining_Method', axis=1)
y = df['Mining_Method']

# 3. Scale numeric features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the scaled data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 0.9

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.99

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.97

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.73

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf')
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)
print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.89

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define model names and predictions
models = {
    'Logistic Regression': y_pred_lr,
    'Decision Tree': y_pred_dt,
    'Random Forest': y_pred_rf,
    'KNN': y_pred_knn,
    'SVM': y_pred_svm
}

# Loop through each model for evaluation
for model_name, y_pred in models.items():
    print(f"\n🔎 Classification Report - {model_name}")
    print(classification_report(y_test, y_pred))

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'📊 Confusion Matrix - {model_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()
# Out:
# 🔎 Classification Report - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92        20
#            1       0.86      1.00      0.92        12
#            2       0.97      0.87      0.92        38
#            3       0.82      0.90      0.86        30
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.92      0.90       100
# weighted avg       0.91      0.90      0.90       100
# <ipython-input-47-c585a2b1c790>:26: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 🔎 Classification Report - Decision Tree
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
# ...

# %%
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Store model names and predictions
model_preds = {
    'Logistic Regression': y_pred_lr,
    'Decision Tree': y_pred_dt,
    'KNN': y_pred_knn
}

# Compute accuracies
accuracies = {model: accuracy_score(y_test, y_pred) for model, y_pred in model_preds.items()}

# Plot
plt.figure(figsize=(8, 5))
plt.bar(accuracies.keys(), accuracies.values(), color='skyblue')
plt.ylabel('Accuracy')
plt.title('📈 Model Accuracy Comparison')
plt.ylim(0, 1)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-77-99062285e69f>:21: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np

# Feature names (same order as X_scaled before scaling)
feature_names = X.columns

# Random Forest Feature Importance
importances_rf = rf.feature_importances_
indices_rf = np.argsort(importances_rf)[::-1]

# Plot Random Forest feature importance
plt.figure(figsize=(10, 5))
sns.barplot(x=importances_rf[indices_rf], y=feature_names[indices_rf], palette='viridis')
plt.title('🌲 Feature Importance - Random Forest')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-49-d82176a45fb8>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importances_rf[indices_rf], y=feature_names[indices_rf], palette='viridis')
# <ipython-input-49-d82176a45fb8>:16: UserWarning: Glyph 127794 (\N{EVERGREEN TREE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127794 (\N{EVERGREEN TREE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Set plot style
sns.set(style="whitegrid")

# 1. Numeric features — use boxplots
numeric_cols = ['Depth_m', 'Ore_Grade', 'Stripping_Ratio', 'Capital_Cost_Million_INR',
                'Operating_Cost_per_Ton_INR', 'Annual_Production_Tons', 'Mine_Life_Years',
                'NPV_Million_INR', 'IRR_Percent', 'Payback_Period_Years', 'Profitability_Index']

for col in numeric_cols:
    plt.figure(figsize=(9, 5))
    sns.boxplot(data=df, x='Mining_Method', y=col, palette='pastel')
    plt.title(f'{col} vs Mining Method')
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()

# 2. Categorical features — use countplots
categorical_cols = ['Labor_Intensity', 'Mechanization_Level']

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, hue='Mining_Method', palette='Set2')
    plt.title(f'{col} Distribution by Mining Method')
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-52-eaf16bcd5790>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Mining_Method', y=col, palette='pastel')
# <ipython-input-52-eaf16bcd5790>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Mining_Method', y=col, palette='pastel')
# <ipython-input-52-eaf16bcd5790>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Mining_Method', y=col, palette='pastel')
# <ipython-input-52-eaf16bcd5790>:15: FutureWarning:
#
# ...

# %%
import pickle

with open('random_forest_model.pkl', 'wb') as f:
    pickle.dump(rf, f)
